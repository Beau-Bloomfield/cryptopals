# %%
# As before, I used Dr. Paccagnella's implementation as a guide in several areas
# https://github.com/ricpacca/cryptopals/blob/master/S6C47.py
# This code works, but only if RSA BIT_STRENGTH is set <= 32... I'll try to address this issue in solution2.ipynb

from RSA import BIT_STRENGTH, RSAClient, RSAServer
from random import choice, randint
from math import ceil, floor

def PCKS1Pad(plaintext: bytes, k = BIT_STRENGTH//8):
    # k is maximum plaintext length in bytes
    assert type(plaintext) is bytes
    #assert len(plaintext) <= k-11
    
    padding = [ 1+choice(range(0xFF)) for pad in range(k-3-len(plaintext)) ]
    assert not any( char == 0x00 for char in padding )
    # Omit the following requirement in order to make this work with smaller bit sizes
    # assert len(padding) >= 8
    return b'\x00\x02' + bytes(padding) + b'\x00' + plaintext


def PCKS1Check(encryption_block: bytes):
    assert type(encryption_block) is bytes

    if encryption_block[:2] == b'\x00\x02':
        return True
    else:
        return False
    
def PCKS1UnPad(plaintext: bytes):
    assert PCKS1Check(plaintext)
    plaintext = plaintext[2:]
    index = plaintext.index(b'\x00')
    return plaintext[1+index:]

class PCKS1Oracle(RSAServer):
    def PCKS1Check(self, ciphertext: int):
        # The cryptopals instructions say this method only needs to check the first two bytes
        # But Dr. Paccgnella's implementation says it needs to check the length in order to work
        # and he spent "hours" debugging this issue, so I'm going to do this preemptively.
        encryption_block = self.DecryptBytes(ciphertext)
        return PCKS1Check( encryption_block ) and len(encryption_block) == ceil(self.n.bit_length() / 8)

# %%
# B-1 is the greatest integer that can be encrypted, 
# excluding the two bytes required for the 0x0002 prefix
# So B would correspond to 0x0001..., so 2B = 0x0002... and 3B = 0x06... = 0b00000000,00000110...

k = BIT_STRENGTH//8
B = 2 ** (8*(k-2))

# %%
# If a number passes the oracle, it must be in [2B, 3B), because 3B would be invalid
# This is not biconditional, however

# %%
oracle = PCKS1Oracle()
pubkey = oracle.GetPubkey()
client = RSAClient(**pubkey)
print(pubkey)
# Out:
# {'e': 3, 'n': 188478984289217058843179473033845902263}

# %%
# Check that everything is working

message = b'B'* (BIT_STRENGTH//8 - 3)
print(padded_message := PCKS1Pad(message))
ciphertext = client.Encrypt(padded_message)
assert oracle.PCKS1Check(ciphertext)
assert PCKS1UnPad(oracle.DecryptBytes(ciphertext)) == message
# Out:
# b'\x00\x02\x00BBBBBBBBBBBBB'

# %%
# Now do the attack, starting with the 
# Step 1 "blinding" step

solution = None
i = 0
e, n = pubkey['e'], pubkey['n']

c = int(ciphertext)
s0 = 1

while True:
    if oracle.PCKS1Check(c * pow(s0, e, n) % n):
        c0 = (c * pow(s0, e, n)) % n
        M0 = [(2*B, 3*B-1)]
        i = 1
        break
    else:
        s0 = randint(0, n-1)

print(f'{i = }, {s0 = }, {c0 = }')
# Out:
# i = 1, s0 = 1, c0 = 20772190901912705312589267864765407570

# %%
# Step 2a

assert i == 1 and oracle.PCKS1Check(c0)

s1 = ceil(n/(3*B))

while not oracle.PCKS1Check(c0 * pow(s1, e, n) % n):
    s1 += 1
c1 = c0 * pow(s1, e, n) % n
i = 2
M1 = M0
print(f'{i = }, {s1 = }, {c1 = }')
# Out:
# i = 2, s1 = 18142, c1 = 113464470718402724241273496440611333115

# %%
M = M1
s = s1

while solution is None:
    print(f'{i = }')
    # Step 2b
    
    assert i > 1

    if len(M) >= 2:
        print('\tM has at least two elements')
        s += 1
        while not oracle.PCKS1Check(c0 * pow(s, e, n) % n):
            s += 1
    elif len(M) == 1:
        print('\tM has one element')
        [(a, b)] = M
        assert b >= a

        if a == b:
            # the interval is fully closed and this must be the solution
            solution = a
            break
            
        r = ceil(2 * (b * s - 2 * B) / n)
        s = ceil((2 * B + r * n) / b)
        print(f'\t{r=}, {s=}')

        while not oracle.PCKS1Check(c0 * pow(s, e, n) % n):
            assert s < n
            assert r < n
            s += 1
            if not s < (3*B + r*n) / a:
                r += 1
                s = ceil((2 * B + r * n) / b)

    else:
        # This should not happen
        assert False
        
    # Step 3
    print('Starting step 3')
    Mnew = []
    for a, b in M:
        r_values = range(ceil((a*s - 3*B + 1)/n), 1+floor((b*s - 2*B)/n))
        print(f'{len(r_values)=}')
        for r in r_values:
            anew =  ceil( (2*B + r*n)/s )
            bnew = floor( (3*B - 1 + r*n)/s )
            Mnew += [ (max(a, anew), min(b, bnew)) ]
    M = list(set(Mnew))
    i += 1
# Out:
# i = 2
# 	M has one element
# 	r=3, s=36301
# Starting step 3
# len(r_values)=2
# i = 3
# 	M has at least two elements
# Starting step 3
# len(r_values)=0
# len(r_values)=1
# i = 4
# 	M has one element
# 	r=15, s=272111
# Starting step 3
# len(r_values)=1
# i = 5
# 	M has one element
# 	r=35, s=634925
# Starting step 3
# len(r_values)=1
# i = 6
# 	M has one element
# 	r=75, s=1360553
# Starting step 3
# len(r_values)=1
# i = 7
# 	M has one element
# 	r=153, s=2775527
# Starting step 3
# len(r_values)=1
# i = 8
# 	M has one element
# 	r=311, s=5641757
# Starting step 3
# len(r_values)=1
# i = 9
# 	M has one element
# 	r=627, s=11374217
# Starting step 3
# len(r_values)=1
# i = 10
# 	M has one element
# 	r=1257, s=22802855
# Starting step 3
# len(r_values)=1
# i = 11
# 	M has one element
# 	r=2519, s=45696413
# Starting step 3
# len(r_values)=1
# i = 12
# 	M has one element
# 	r=5041, s=91447247
# Starting step 3
# len(r_values)=1
# i = 13
# 	M has one element
# 	r=10083, s=182912635
# Starting step 3
# len(r_values)=1
# i = 14
# 	M has one element
# 	r=20167, s=365843410
# Starting step 3
# len(r_values)=1
# i = 15
# 	M has one element
# 	r=40337, s=731741240
# Starting step 3
# len(r_values)=1
# i = 16
# 	M has one element
# 	r=80679, s=1463573182
# Starting step 3
# len(r_values)=1
# i = 17
# 	M has one element
# 	r=161361, s=2927200784
# Starting step 3
# len(r_values)=1
# i = 18
# 	M has one element
# 	r=322727, s=5854492269
# Starting step 3
# len(r_values)=1
# i = 19
# 	M has one element
# 	r=645457, s=11709038959
# Starting step 3
# len(r_values)=1
# i = 20
# 	M has one element
# 	r=1290915, s=23418096059
# Starting step 3
# len(r_values)=1
# i = 21
# 	M has one element
# 	r=2581833, s=46836246539
# Starting step 3
# len(r_values)=1
# i = 22
# 	M has one element
# 	r=5163669, s=93672547499
# Starting step 3
# len(r_values)=1
# i = 23
# 	M has one element
# 	r=10327343, s=187345185701
# Starting step 3
# len(r_values)=1
# i = 24
# 	M has one element
# 	r=20654691, s=374690462105
# Starting step 3
# len(r_values)=1
# i = 25
# 	M has one element
# 	r=41309385, s=749380978631
# Starting step 3
# len(r_values)=1
# i = 26
# 	M has one element
# 	r=82618775, s=1498762047965
# Starting step 3
# len(r_values)=1
# i = 27
# 	M has one element
# 	r=165237553, s=2997524150351
# Starting step 3
# len(r_values)=1
# i = 28
# 	M has one element
# 	r=330475111, s=5995048391405
# Starting step 3
# len(r_values)=1
# i = 29
# 	M has one element
# 	r=660950225, s=11990096837231
# Starting step 3
# len(r_values)=1
# i = 30
# 	M has one element
# 	r=1321900451, s=23980193692603
# Starting step 3
# len(r_values)=1
# i = 31
# 	M has one element
# 	r=2643800903, s=47960387403346
# Starting step 3
# len(r_values)=1
# i = 32
# 	M has one element
# 	r=5287601811, s=95920774897393
# Starting step 3
# len(r_values)=1
# i = 33
# 	M has one element
# 	r=10575203625, s=191841549849207
# Starting step 3
# len(r_values)=1
# i = 34
# 	M has one element
# 	r=21150407251, s=383683099716555
# Starting step 3
# len(r_values)=1
# i = 35
# 	M has one element
# 	r=42300814505, s=767366199487531
# Starting step 3
# len(r_values)=1
# i = 36
# 	M has one element
# 	r=84601629013, s=1534732399029483
# Starting step 3
# len(r_values)=1
# i = 37
# 	M has one element
# 	r=169203258031, s=3069464798149669
# Starting step 3
# len(r_values)=1
# i = 38
# 	M has one element
# 	r=338406516067, s=6138929596390040
# Starting step 3
# len(r_values)=1
# i = 39
# 	M has one element

# %%
cracked_message = solution.to_bytes(byteorder='big', length = BIT_STRENGTH//8)
print(cracked_message)
print(padded_message)
# Out:
# b'\x00\x02\x00BBBBB@\x00\x00\x00\x00\x00\x00\x00'
# b'\x00\x02\x00BBBBBBBBBBBBB'

# %%
# So, for some reason this solution works, but only for the first eight bytes...
# Not sure why this is.  I'll come back to this issue later.
